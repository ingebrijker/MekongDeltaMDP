# %% [markdown]
# # Compiling of Data
# This is where final output is generated, like figures and tables. Make sure to import the data_processing file as input.

# %%
import data_processing as processing_data


file_path = "2025_Data_WaterDepth.txt"
